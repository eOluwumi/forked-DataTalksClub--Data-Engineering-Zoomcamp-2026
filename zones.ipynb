# %%
# Verify data was loaded successfully
result = pd.read_sql('SELECT COUNT(*) as count FROM taxi_zones', con=engine)
print(f"Total zones loaded: {result['count'].values[0]}")
print("\nFirst few zones:")
pd.read_sql('SELECT * FROM taxi_zones LIMIT 5', con=engine)
# Out:
# Total zones loaded: 265
#
# First few zones:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df.to_sql(name='taxi_zones', con=engine, if_exists='replace', index=False)
# Out:
# 265

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
# !uv add sqlalchemy psycopg2.binary
# Out:
# Resolved 119 packages in 0.70ms
# Audited 10 packages in 0.20ms

# %%
print(df.columns)
print(df.head())
# Out:
# Index(['LocationID', 'Borough', 'Zone', 'service_zone'], dtype='str')
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df['LocationID']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 260    261
# 261    262
# 262    263
# 263    264
# 264    265
# Name: LocationID, Length: 265, dtype: int64

# %%
url = 'https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv'
df = pd.read_csv(url)

# %%
import pandas as pd
