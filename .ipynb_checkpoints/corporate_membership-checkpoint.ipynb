# %%
# Verify data was loaded successfully
result = pd.read_sql('SELECT COUNT(*) as count FROM corporate_membership', con=engine)
print(f"Total corporate membership records loaded: {result['count'].values[0]}")
print("\nFirst few records:")
pd.read_sql('SELECT * FROM corporate_membership LIMIT 5', con=engine)

# %%
df.to_sql(name='corporate_membership', con=engine, if_exists='replace', index=False)

# %%
# Clean column names - convert to lowercase and replace spaces with underscores
df.columns = df.columns.str.lower().str.replace(' ', '_').str.replace('-', '_')

# Display cleaned columns
print("Cleaned columns:")
print(df.columns.tolist())

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
# !uv add sqlalchemy psycopg2.binary

# %%
print(df.info())
print("\nData types:")
print(df.dtypes)

# %%
print("Columns:")
print(df.columns.tolist())
print("\nData shape:", df.shape)
print("\nFirst few rows:")
print(df.head())

# %%
len(df)

# %%
# Convert Google Sheets URL to CSV export format
sheet_id = '1VdDqzv2CalQuYtbuHYyw4T57qvuLtLfI'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv'
df = pd.read_csv(url)

# %%
import pandas as pd
